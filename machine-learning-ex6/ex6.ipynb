# %% [markdown]
# #  Ex6: Support Vector Machines
# ## =============== Part 1: Loading and Visualizing Data ================
#   We start the exercise by first loading and visualizing the dataset.
#   The following code will load the dataset into your environment and plot
#   the data.

# %%
from pathlib import *
# %run ../cs229config.py
exppath = str(PurePath(cs229basepath(),'machine-learning-ex6','ex6'))
print("CS229:"+exppath)
# Out:
# CS229:C:\data\网络资源-吴恩达机器学习课程\编程作业\machine-learning-ex6\ex6

# %%
# Load Training Data
print('Loading and Visualizing Data ...')
import pandas as pd
import numpy as np
from scipy.io import loadmat
data = loadmat(PurePath(exppath,'ex6data1.mat'))
print(data.keys())
# Load from ex6data1: 
# You will have X, y in your environment
X = data['X']
y = data['y']
print("X shape:",X.shape,",y shape:",y.shape)
# print(X[(y>0).reshape(-1)][:,0].shape)
# print(y[y>0].shape)
# Out:
# Loading and Visualizing Data ...
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])
# X shape: (51, 2) ,y shape: (51, 1)

# %%
# Plot training data
# %matplotlib inline
from plotData import plotData # cs229
plotData(X, y)
print('Program paused. Press enter to continue.')
# Out:
# Program paused. Press enter to continue.

# %% [markdown]
# ## ==================== Part 2: Training Linear SVM ====================
#   The following code will train a linear SVM on the dataset and plot the
#   decision boundary learned.

# %%
# Load Training Data
print('Training Linear SVM ...')
import pandas as pd
import numpy as np
from scipy.io import loadmat
data = loadmat(PurePath(exppath,'ex6data1.mat'))
print(data.keys())
# Load from ex6data1: 
# You will have X, y in your environment
X = data['X']
y = data['y']
print("X shape:",X.shape,",y shape:",y.shape)
# Out:
# Training Linear SVM ...
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])
# X shape: (51, 2) ,y shape: (51, 1)

# %% [markdown]
#  You should try to change the C value below and see how the decision
#  boundary varies (e.g., try C = 1000)

# %%
# C = 1;
# model = svmTrain(X, y, C, @linearKernel, 1e-3, 20);
# visualizeBoundaryLinear(X, y, model);
print('Program paused. Press enter to continue.')
# Out:
# Program paused. Press enter to continue.

# %% [markdown]
# ## =============== Part 3: Implementing Gaussian Kernel ===============
#   You will now implement the Gaussian kernel to use
#   with the SVM. You should complete the code in gaussianKernel.m

# %%
print('Evaluating the Gaussian Kernel ...')
x1 = np.array([1, 2, 1])
x2 = np.array([0, 4, -1]) 
sigma = 2

# %% [markdown]
# ## =============== Part 4: Visualizing Dataset 2 ================
#   The following code will load the next dataset into your environment and
#   plot the data.

# %%
print('Loading and Visualizing Data ...')
data2 = loadmat(PurePath(exppath,'ex6data2.mat'))
print(data2.keys())
# Load from ex6data2: 
# You will have X, y in your environment
# Plot training data
X_ = data2['X']
y_ = data2['y']
print("X shape:",X_.shape,",y shape:",y_.shape)
# %matplotlib inline
from plotData import plotData # cs229
plotData(X_, y_)
print('Program paused. Press enter to continue.')
# Out:
# Loading and Visualizing Data ...
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])
# X shape: (51, 2) ,y shape: (51, 1)
# Program paused. Press enter to continue.

# %% [markdown]
# ## ========== Part 5: Training SVM with RBF Kernel (Dataset 2) ==========
#   After you have implemented the kernel, we can now use it to train the
#   SVM classifier.

# %%
print('\nTraining SVM with RBF Kernel (this may take 1 to 2 minutes) ...')
# Load from ex6data2: 
# You will have X, y in your environment
data2 = loadmat(PurePath(exppath,'ex6data2.mat'))
X_ = data2['X']
y_ = data2['y']

# %% [markdown]
# ## =============== Part 6: Visualizing Dataset 3 ================
#   The following code will load the next dataset into your environment and
#   plot the data.

# %%
print('Loading and Visualizing Data ...')
data3 = loadmat(PurePath(exppath,'ex6data3.mat'))
print(data3.keys())
# Load from ex6data3: 
# You will have X, y in your environment
# Plot training data
X__ = data3['X']
y__ = data3['y']
print("X shape:",X__.shape,",y shape:",y__.shape)
# %matplotlib inline
from plotData import plotData # cs229
plotData(X__, y__)
print('Program paused. Press enter to continue.')
# Out:
# Loading and Visualizing Data ...
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y', 'yval', 'Xval'])
# X shape: (211, 2) ,y shape: (211, 1)
# Program paused. Press enter to continue.
